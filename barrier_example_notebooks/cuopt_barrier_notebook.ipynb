# %% [markdown]
# # Using cuOpt's Barrier Solver
#
# The new solver may be accessed through any of cuOpt’s existing APIs or interfaces. These include:
# * Python modeling API
# * C API
# * AMPL
# * PuLP
# * CVXPY
# * Julia/JuMP
# * Command-line interface
#
# This notebook shows how to use the new solver from the command-line to solve linear programs defined in MPS files:

# %% [markdown]
# You should first enable conda inside this notebook:

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:08
# 🔁 Restarting kernel...

# %% [markdown]
# You can install cuOpt from the command-line, using conda, via the command-below. **Note: this command can take a few minutes to run**. Remove the `%%capture` line to see the progress.

# %%
# %%capture
# !conda install -c rapidsai-nightly -c conda-forge -c nvidia cuopt-server=25.10.* cuopt-sh-client=25.10.*

# %% [markdown]
# A large linear program defined in an MPS file may be downloaded via:

# %%
# !wget https://plato.asu.edu/ftp/lptestset/s100.mps.bz2
# Out:
# --2025-10-20 16:54:06--  https://plato.asu.edu/ftp/lptestset/s100.mps.bz2
# Resolving plato.asu.edu (plato.asu.edu)... 129.219.51.85
# Connecting to plato.asu.edu (plato.asu.edu)|129.219.51.85|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6741947 (6.4M) [application/x-bzip2]
# Saving to: ‘s100.mps.bz2’
#
# s100.mps.bz2        100%[===================>]   6.43M  --.-KB/s    in 0.1s
#
# 2025-10-20 16:54:06 (46.9 MB/s) - ‘s100.mps.bz2’ saved [6741947/6741947]

# %% [markdown]
# You can then solve the problem with cuOpt’s command-line interface via:

# %%
# !cuopt_cli --method=3 s100.mps.bz2
# Out:
# Setting parameter method to 3
# Reading file s100.mps.bz2
# cuOpt version: 25.10.0, git hash: ab1cc2b, host arch: x86_64, device archs: 70-real,75-real,80-real,86-real,90a-real,100f-real,120a-real,120
# CPU: Intel(R) Xeon(R) CPU @ 2.00GHz, threads (physical/logical): 1/2, RAM: 0.76 GiB
# CUDA 12.9, device: Tesla T4 (ID 0), VRAM: 14.74 GiB
# CUDA device UUID: ffffffc1fffffffd1cffffffeb-ffffffdaf
#
# Solving a problem with 14733 constraints, 364417 variables (0 integers), and 1777917 nonzeros
# Problem scaling:
# Objective coefficents range:          [3e-03, 5e-03]
# Constraint matrix coefficients range: [1e+00, 3e+04]
# Constraint rhs / bounds range:        [1e+00, 9e+04]
# Variable bounds range:                [0e+00, 1e+00]
#
# Third-party presolve is disabled, skipping
# Objective offset 0.000000 scaling_factor 1.000000
# Presolve attempt to remove 80 empty cols
# Folding: Number of colors exceeds threshold
# Folding: Coloring aborted in 0.68 seconds
# Presolve eliminated 80 variables
# Presolved problem: 14733 constraints 364552 variables 1778132 nonzeros
# Scaling matrix. Maximum column norm 3.460500e+04
# Barrier solver: 14733 constraints, 364552 variables, 1778132 nonzeros
#
# Upper bounds                : 364337
# Density estimator time      : 0.00s
# Linear system               : ADAT
# cuDSS Version               : 0.7.0
# cuDSS Threading layer       : libcudss_mtlayer_gomp.so.0
# ADAT time                   : 0.06s
# ADAT nonzeros               : 1.88e+06
# ADAT density                : 0.01
# Reordering time             : 0.32s
# Symbolic factorization time : 0.09s
# Total symbolic time         : 0.41s
# Symbolic nonzeros in factor : 3.70e+06
#
#                   Objective                         Infeasibility        Time
#  91   -1.693585239879e-01 -1.731114486465e-01 6.47e-13 1.57e-11 5.28e-06 13.0
#  92   -1.697533204027e-01 -1.721745754476e-01 4.34e-13 1.47e-11 2.90e-06 13.2
#  93   -1.701070308363e-01 -1.719765636371e-01 3.06e-13 1.49e-11 1.81e-06 13.3
#  94   -1.703946601135e-01 -1.717171683558e-01 2.06e-13 1.48e-11 9.87e-07 13.4
#  95   -1.707329557765e-01 -1.713887944352e-01 1.27e-13 1.52e-11 4.65e-07 13.5
#  96   -1.708955174124e-01 -1.711936856154e-01 6.77e-14 1.55e-11 9.81e-08 13.7
#  97   -1.709615905936e-01 -1.711337898159e-01 2.44e-13 1.48e-11 2.61e-08 13.8
#  98   -1.710503964970e-01 -1.711171464995e-01 8.50e-13 1.56e-11 6.29e-09 13.9
#
# Optimal solution found in 98 iterations and 13.90s
# Objective -1.71050396e-01
# Primal infeasibility (abs/rel): 7.71e-08/8.50e-13
# Dual infeasibility   (abs/rel): 1.56e-11/1.56e-11
# Complementarity gap  (abs/rel): 7.36e-09/6.29e-09
#
# Unscaled Primal infeasibility   (abs/rel): 7.70e-08/8.49e-13
# Unscaled Dual infeasibility     (abs/rel): 1.96e-11/1.95e-11
# Post-solve: Handling removed variables 80
# Post-solve Primal infeasibility (abs/rel): 7.70e-08/8.49e-13
# Post-solve Dual infeasibility   (abs/rel): 1.96e-11/1.95e-11
# Barrier finished in 14.52 seconds

# %% [markdown]
# Note that inside this Google Colab Notebok, cuOpt is running on a T4 GPU. So these solve times are not representative of what you would see on a recommend GPU such as an H100.

# %% [markdown]
# # Deterministic Mode
# By default cuOpt uses cuDSS in non-deterministic mode. This means that cuDSS may produce a (slightly) different solution, given the same inputs. cuOpt inherits the non-determinism from cuDSS. If determinism is important for your application, you can set the parameter “cudss-deterministic”  to true. This will put cuDSS in a deterministic mode.

# %%
# !cuopt_cli --method=3 --cudss-deterministic=t s100.mps.bz2
# Out:
# Setting parameter cudss_deterministic to true
# Setting parameter method to 3
# Reading file s100.mps.bz2
# cuOpt version: 25.10.0, git hash: ab1cc2b, host arch: x86_64, device archs: 70-real,75-real,80-real,86-real,90a-real,100f-real,120a-real,120
# CPU: Intel(R) Xeon(R) CPU @ 2.00GHz, threads (physical/logical): 1/2, RAM: 0.64 GiB
# CUDA 12.9, device: Tesla T4 (ID 0), VRAM: 14.74 GiB
# CUDA device UUID: ffffffc1fffffffd1cffffffeb-ffffffdaf
#
# Solving a problem with 14733 constraints, 364417 variables (0 integers), and 1777917 nonzeros
# Problem scaling:
# Objective coefficents range:          [3e-03, 5e-03]
# Constraint matrix coefficients range: [1e+00, 3e+04]
# Constraint rhs / bounds range:        [1e+00, 9e+04]
# Variable bounds range:                [0e+00, 1e+00]
#
# Third-party presolve is disabled, skipping
# Objective offset 0.000000 scaling_factor 1.000000
# Presolve attempt to remove 80 empty cols
# Folding: Number of colors exceeds threshold
# Folding: Coloring aborted in 0.67 seconds
# Presolve eliminated 80 variables
# Presolved problem: 14733 constraints 364552 variables 1778132 nonzeros
# Scaling matrix. Maximum column norm 3.460500e+04
#  86   -1.670584655036e-01 -1.764211663394e-01 2.49e-12 2.49e-11 8.13e-06 15.0
#  87   -1.679228113959e-01 -1.751516500372e-01 1.79e-12 2.54e-11 6.89e-06 15.2
#  88   -1.682431277155e-01 -1.747737929109e-01 1.39e-12 2.56e-11 4.57e-06 15.3
#  89   -1.685530598952e-01 -1.744788408396e-01 1.09e-12 3.05e-11 3.36e-05 15.5
#  90   -1.689840971857e-01 -1.741707042092e-01 7.83e-13 2.92e-11 1.53e-05 15.6
#  91   -1.693583071437e-01 -1.731121668709e-01 5.77e-13 2.41e-11 5.28e-06 15.8
#  92   -1.697531286708e-01 -1.721748111886e-01 3.83e-13 1.97e-11 2.90e-06 15.9
#  93   -1.701065613436e-01 -1.719767708564e-01 2.47e-13 2.45e-11 1.81e-06 16.1
#  94   -1.703939616417e-01 -1.717173560755e-01 1.65e-13 2.51e-11 9.88e-07 16.2
#  95   -1.707322331885e-01 -1.713888706290e-01 8.14e-14 2.05e-11 4.65e-07 16.4
#  96   -1.708949940479e-01 -1.711935134954e-01 5.23e-14 2.13e-11 9.84e-08 16.5
#  97   -1.709611871332e-01 -1.711337894667e-01 3.37e-14 2.02e-11 2.61e-08 16.7
#  98   -1.710501829991e-01 -1.711171484203e-01 3.71e-13 2.02e-11 6.30e-09 16.9
#
# Optimal solution found in 98 iterations and 16.85s
# Objective -1.71050183e-01
# Primal infeasibility (abs/rel): 3.37e-08/3.71e-13
# Dual infeasibility   (abs/rel): 2.02e-11/2.02e-11
# Complementarity gap  (abs/rel): 7.38e-09/6.30e-09
#
# Unscaled Primal infeasibility   (abs/rel): 3.36e-08/3.71e-13
# Unscaled Dual infeasibility     (abs/rel): 3.64e-11/3.63e-11
# Post-solve: Handling removed variables 80
# Post-solve Primal infeasibility (abs/rel): 3.36e-08/3.71e-13
# Post-solve Dual infeasibility   (abs/rel): 3.64e-11/3.63e-11
# Barrier finished in 17.29 seconds

# %% [markdown]
# In our testing, cuDSS is about 1.5X slower in factorization and solve time when deterministic. This translates almost directly to a slowdown in cuOpt’s barrier method.

# %% [markdown]
# #Folding
#
# Linear programs often include symmetries. For example, two variables may appear in identical constraints, with identical costs and bounds. We can take advantage of these symmetries to dramatically reduce the size of the linear program. This size reduction often comes with a dramatic reduction in the solve time. This process is often referred to as folding a linear program.  Folding was developed by Grohe et. al in their 2014 paper: [Dimension Reduction via Colour Refinement](https://arxiv.org/pdf/1307.5697).
#
# Folding can result in large reductions in run-time. But to fold a linear program, a graph representation of the problem must first be colored using the [color refinement algorithm](https://www.lics.rwth-aachen.de/global/show_document.asp?id=aaaaaaaaabbtcqu). cuOpt includes a CPU implementation of the color refinement algorithm. On some LPs, coloring this graph can take longer than solving the original linear program. So cuOpt includes heuristics to decide when to try to fold an LP and when to abort coloring. These heuristics ensure good performance on average, but you may want to enable or disable folding on your own problems.
#
# You can control folding via the folding parameter. The default value of (-1) uses these heuristics to decide automatically to fold or not, you can turn folding off by setting the parameter to 0, or force folding on by setting the parameter to (1).

# %% [markdown]
# We first download an example LP that solves quickly when cuOpt automatically detects the problem can be folded.

# %%
# !wget https://plato.asu.edu/ftp/lptestset/qap15.mps.bz2
# Out:
# --2025-10-20 16:58:28--  https://plato.asu.edu/ftp/lptestset/qap15.mps.bz2
# Resolving plato.asu.edu (plato.asu.edu)... 129.219.51.85
# Connecting to plato.asu.edu (plato.asu.edu)|129.219.51.85|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 282733 (276K) [application/x-bzip2]
# Saving to: ‘qap15.mps.bz2’
#
# qap15.mps.bz2       100%[===================>] 276.11K  --.-KB/s    in 0.06s
#
# 2025-10-20 16:58:28 (4.79 MB/s) - ‘qap15.mps.bz2’ saved [282733/282733]

# %% [markdown]
# We now run cuOpt on the LP. Note that we don't need to specify folding. cuOpt automatically attempts to fold

# %%
# !cuopt_cli --method=3 qap15.mps.bz2
# Out:
# Setting parameter method to 3
# Reading file qap15.mps.bz2
# cuOpt version: 25.10.0, git hash: ab1cc2b, host arch: x86_64, device archs: 70-real,75-real,80-real,86-real,90a-real,100f-real,120a-real,120
# CPU: Intel(R) Xeon(R) CPU @ 2.00GHz, threads (physical/logical): 1/2, RAM: 0.91 GiB
# CUDA 12.9, device: Tesla T4 (ID 0), VRAM: 14.74 GiB
# CUDA device UUID: ffffffc1fffffffd1cffffffeb-ffffffdaf
#
# Solving a problem with 6330 constraints, 22275 variables (0 integers), and 94950 nonzeros
# Problem scaling:
# Objective coefficents range:          [2e+00, 1e+02]
# Constraint matrix coefficients range: [1e+00, 1e+00]
# Constraint rhs / bounds range:        [1e+00, 1e+00]
# Variable bounds range:                [0e+00, 0e+00]
#
# Third-party presolve is disabled, skipping
# Objective offset 0.000000 scaling_factor 1.000000
# Folding: Colors 8093. Refinements: 8094
# Folding: Coloring time 0.03 seconds
# Folding: Constructing reduced problem: 2121 constraints 5970 variables and 25800 nonzeros
# Folding: time 0.04 seconds
# Presolve eliminated 4209 constraints
# Presolve eliminated 16305 variables
# Presolved problem: 2121 constraints 5970 variables 25800 nonzeros
# Scaling matrix. Maximum column norm 6.633250e+00
# Barrier solver: 2121 constraints, 5970 variables, 25800 nonzeros
#
# Density estimator time      : 0.00s
# Linear system               : ADAT
# cuDSS Version               : 0.7.0
# cuDSS Threading layer       : libcudss_mtlayer_gomp.so.0
# ADAT time                   : 0.00s
# ADAT nonzeros               : 1.01e+05
# ADAT density                : 0.02
# Reordering time             : 0.05s
# Symbolic factorization time : 0.05s
# Total symbolic time         : 0.10s
# Symbolic nonzeros in factor : 1.08e+06
#
#                   Objective                         Infeasibility        Time
# Iter   Primal              Dual                Primal   Dual    Compl.   Elapsed
#   0   +1.584000000000e+03 +0.000000000000e+00 2.63e-14 1.00e+01 4.42e+00 0.2
#   1   +1.460986551396e+03 +6.304743168424e+02 1.33e-14 1.39e-02 9.05e-04 0.3
#   2   +1.359630529769e+03 +7.965251090127e+02 7.13e-15 5.34e-03 5.55e-04 0.3
#   3   +1.244859544141e+03 +9.041633793288e+02 5.30e-14 2.68e-03 6.73e-04 0.4
#   4   +1.170034192472e+03 +9.644928917209e+02 4.12e-14 1.09e-03 3.10e-04 0.4
#   5   +1.135665117228e+03 +1.001933585119e+03 3.79e-14 4.22e-04 1.75e-04 0.4
#   6   +1.095401368258e+03 +1.018232041829e+03 5.64e-14 2.24e-04 1.00e-04 0.5
#   7   +1.071853746365e+03 +1.026726193967e+03 4.71e-14 1.22e-04 2.76e-05 0.5
#   8   +1.057441812131e+03 +1.032616682782e+03 3.01e-14 6.57e-05 1.92e-05 0.5
#   9   +1.050921527887e+03 +1.035451952469e+03 2.06e-14 4.04e-05 1.39e-05 0.5
#  10   +1.046741658892e+03 +1.037997950798e+03 1.94e-14 1.92e-05 8.57e-06 0.6
#  11   +1.044010021754e+03 +1.039019021105e+03 1.39e-14 1.16e-05 3.81e-06 0.6
#  12   +1.043047533434e+03 +1.040009163370e+03 2.51e-14 5.23e-06 1.88e-06 0.6
#  13   +1.042365904834e+03 +1.040424277923e+03 2.76e-14 1.90e-06 1.68e-06 0.7
#  14   +1.041804441159e+03 +1.040762780536e+03 4.12e-14 5.90e-07 2.02e-06 0.7
#  15   +1.041536737979e+03 +1.040875570469e+03 6.78e-14 1.87e-07 7.03e-07 0.7
#  16   +1.041284081047e+03 +1.040940908392e+03 1.18e-13 7.24e-08 3.05e-07 0.7
#  17   +1.041106355881e+03 +1.040960853436e+03 2.73e-12 3.20e-08 1.47e-07 0.8
#  18   +1.041010147772e+03 +1.040979263186e+03 1.22e-11 1.33e-08 4.72e-08 0.8
#  19   +1.040999018778e+03 +1.040989705958e+03 3.51e-12 3.86e-09 1.11e-08 0.8
#  20   +1.040995319621e+03 +1.040991857719e+03 2.89e-12 1.84e-09 5.71e-09 0.8
#
# Optimal solution found in 20 iterations and 0.84s
# Objective +1.04099532e+03
# Primal infeasibility (abs/rel): 5.79e-12/2.89e-12
# Dual infeasibility   (abs/rel): 4.43e-07/1.84e-09
# Complementarity gap  (abs/rel): 5.95e-06/5.71e-09
#
# Unscaled Primal infeasibility   (abs/rel): 5.79e-12/2.89e-12
# Unscaled Dual infeasibility     (abs/rel): 2.94e-06/6.11e-09
# Unfolded dual residual = 2.030049e-06
# Post-solve Primal infeasibility (abs/rel): 5.79e-12/2.89e-12
# Post-solve Dual infeasibility   (abs/rel): 2.03e-06/1.68e-08
# Barrier finished in 0.89 seconds

# %% [markdown]
# We now solve the same LP but this time we disable folding

# %%
# !cuopt_cli --method=3 --folding=0 qap15.mps.bz2
# Out:
# Setting parameter folding to 0
# Setting parameter method to 3
# Reading file qap15.mps.bz2
# cuOpt version: 25.10.0, git hash: ab1cc2b, host arch: x86_64, device archs: 70-real,75-real,80-real,86-real,90a-real,100f-real,120a-real,120
# CPU: Intel(R) Xeon(R) CPU @ 2.00GHz, threads (physical/logical): 1/2, RAM: 0.91 GiB
# CUDA 12.9, device: Tesla T4 (ID 0), VRAM: 14.74 GiB
# CUDA device UUID: ffffffc1fffffffd1cffffffeb-ffffffdaf
#
# Solving a problem with 6330 constraints, 22275 variables (0 integers), and 94950 nonzeros
# Problem scaling:
# Objective coefficents range:          [2e+00, 1e+02]
# Constraint matrix coefficients range: [1e+00, 1e+00]
# Constraint rhs / bounds range:        [1e+00, 1e+00]
# Primal infeasibility (abs/rel): 1.27e-12/6.33e-13
# Dual infeasibility   (abs/rel): 5.33e-07/8.74e-09
# Complementarity gap  (abs/rel): 1.74e-06/1.67e-09
#
# Unscaled Primal infeasibility   (abs/rel): 1.27e-12/6.33e-13
# Unscaled Dual infeasibility     (abs/rel): 2.92e-06/2.41e-08
# Post-solve Primal infeasibility (abs/rel): 1.27e-12/6.33e-13
# Post-solve Dual infeasibility   (abs/rel): 2.92e-06/2.41e-08
# Barrier finished in 8.37 seconds

# %% [markdown]
# A solve time of 0.94 seconds with folding versus 8.23 seconds without is quite an improvement!

# %% [markdown]
# # Dualize
# This setting controls whether cuOpt decides to solve the dual problem (instead of the primal problem) in presolve. Solving the dual can be faster, especially on problems that have more constraints than variables.
#
# The default value of -1 uses a heuristic to decide automatically whether to solve the dual or not, you can disable dualization by setting the parameter to 0, or force dualization by setting the parameter to 1.
#
# Let us run cuOpt barrier on the supportcase10 problem. Note that we do not need to specify dualize, cuOpt's heuristics automatically determine that the problem would benefit from solving the dual.

# %%
# !wget https://plato.asu.edu/ftp/lptestset/supportcase10.mps.bz2
# Out:
# --2025-10-21 22:53:24--  https://plato.asu.edu/ftp/lptestset/supportcase10.mps.bz2
# Resolving plato.asu.edu (plato.asu.edu)... 129.219.51.85
# Connecting to plato.asu.edu (plato.asu.edu)|129.219.51.85|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2038347 (1.9M) [application/x-bzip2]
# Saving to: ‘supportcase10.mps.bz2’
#
# supportcase10.mps.b 100%[===================>]   1.94M  7.13MB/s    in 0.3s
#
# 2025-10-21 22:53:25 (7.13 MB/s) - ‘supportcase10.mps.bz2’ saved [2038347/2038347]

# %%
# !cuopt_cli --method=3 supportcase10.mps.bz2
# Out:
# Setting parameter method to 3
# Reading file supportcase10.mps.bz2
# cuOpt version: 25.10.0, git hash: ab1cc2b, host arch: x86_64, device archs: 70-real,75-real,80-real,86-real,90a-real,100f-real,120a-real,120
# CPU: Intel(R) Xeon(R) CPU @ 2.20GHz, threads (physical/logical): 1/2, RAM: 0.76 GiB
# CUDA 12.9, device: Tesla T4 (ID 0), VRAM: 14.74 GiB
# CUDA device UUID: ffffffa2ffffffa0ffffff94ffffffc8-2ff
#
# Solving a problem with 165684 constraints, 14770 variables (0 integers), and 555082 nonzeros
# Problem scaling:
# Objective coefficents range:          [1e+00, 1e+00]
# Constraint matrix coefficients range: [1e+00, 1e+00]
# Constraint rhs / bounds range:        [1e+00, 1e+00]
# Variable bounds range:                [0e+00, 1e+00]
#
# Third-party presolve is disabled, skipping
# Objective offset 0.000000 scaling_factor 1.000000
# Solving the dual
# Folding: Number of colors exceeds threshold
# Folding: Coloring aborted in 0.12 seconds
# Presolved problem: 14770 constraints 204884 variables 603942 nonzeros
# Scaling matrix. Maximum column norm 5.567764e+00
# Barrier solver: 14770 constraints, 204884 variables, 603942 nonzeros
#
# Free variables              : 9660
# Density estimator time      : 0.00s
# Linear system               : ADAT
# cuDSS Version               : 0.7.0
# cuDSS Threading layer       : libcudss_mtlayer_gomp.so.0
# ADAT time                   : 0.06s
# ADAT nonzeros               : 1.06e+06
# Post-solve Dual infeasibility   (abs/rel): 4.26e-08/2.13e-08
# Primal objective: 3.383929e+00
# Primal residual (abs/rel): 6.371547e-09/3.185774e-09
# Dual residual (abs/rel): 1.021072e-11/5.105361e-12
# Barrier finished in 16.37 seconds

# %% [markdown]
# Note the `Solving by dual` line in the logs. This means the solver performed dualization. We now solve the same LP but this time we disable dualization. Note this can take a long time to solve, so we set a time limit of three minutes.

# %%
# !cuopt_cli --dualize=0 --method=3 --time-limit=180 supportcase10.mps.bz2
# Out:
# Setting parameter dualize to 0
# Setting parameter method to 3
# Setting parameter time_limit to 1.800000e+02
# Reading file supportcase10.mps.bz2
# cuOpt version: 25.10.0, git hash: ab1cc2b, host arch: x86_64, device archs: 70-real,75-real,80-real,86-real,90a-real,100f-real,120a-real,120
# CPU: Intel(R) Xeon(R) CPU @ 2.20GHz, threads (physical/logical): 1/2, RAM: 4.37 GiB
# CUDA 12.9, device: Tesla T4 (ID 0), VRAM: 14.74 GiB
# CUDA device UUID: ffffffa2ffffffa0ffffff94ffffffc8-2ff
#
# Solving a problem with 165684 constraints, 14770 variables (0 integers), and 555082 nonzeros
# Problem scaling:
# Objective coefficents range:          [1e+00, 1e+00]
# Constraint matrix coefficients range: [1e+00, 1e+00]
# Constraint rhs / bounds range:        [1e+00, 1e+00]
# Variable bounds range:                [0e+00, 1e+00]
#
# Third-party presolve is disabled, skipping
# Objective offset 0.000000 scaling_factor 1.000000
# Presolve attempt to remove 140 empty cols
# Folding: Number of colors exceeds threshold
# Folding: Coloring aborted in 0.32 seconds
# Presolve eliminated 140 variables
# Presolved problem: 165684 constraints 170654 variables 711106 nonzeros
# Scaling matrix. Maximum column norm 6.259393e+01
# Barrier solver: 165684 constraints, 170654 variables, 711106 nonzeros
#
# Upper bounds                : 14630
# Dense columns               : 50
# Dense rows                  : 2
# Density estimator time      : 0.03s
# Linear system               : ADAT
# cuDSS Version               : 0.7.0
# cuDSS Threading layer       : libcudss_mtlayer_gomp.so.0
# ADAT time                   : 0.22s
# ADAT nonzeros               : 6.67e+07
# ADAT density                : 0.00
# Reordering time             : 12.61s
# Symbolic factorization time : 5.11s
# Total symbolic time         : 17.72s
# Symbolic nonzeros in factor : 5.52e+08
#
#                   Objective                         Infeasibility        Time
# Iter   Primal              Dual                Primal   Dual    Compl.   Elapsed
#   0   +4.476152420588e+01 -1.926291313423e+05 5.35e+01 1.00e+01 1.68e+02 102.8
# Barrier time limit exceeded
# Barrier finished in 187.60 seconds

# %% [markdown]
# ### **Ordering**
# This setting controls the ordering algorithm used by cuDSS for sparse factorizations. The ordering can significantly impact solver run time.
#
# The default setting of `-1` use a heuristic to select the best ordering. The settiong of `0` uses the `cuDSS` default ordering. The setting of `1` use the Approximate Minimum Degree ordering.
#
# Let us run cuOpt barrier with different ordering algorithms on **set-cover-model.mps** problem. First we will run the cuDSS default ordering and inspect the solve time.

# %%
# !wget https://plato.asu.edu/ftp/lptestset/set-cover-model.mps.bz2
# Out:
# --2025-10-21 23:07:10--  https://plato.asu.edu/ftp/lptestset/set-cover-model.mps.bz2
# Resolving plato.asu.edu (plato.asu.edu)... 129.219.51.85
# Connecting to plato.asu.edu (plato.asu.edu)|129.219.51.85|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73534965 (70M) [application/x-bzip2]
# Saving to: ‘set-cover-model.mps.bz2’
#
# set-cover-model.mps 100%[===================>]  70.13M  54.1MB/s    in 1.3s
#
# 2025-10-21 23:07:11 (54.1 MB/s) - ‘set-cover-model.mps.bz2’ saved [73534965/73534965]

# %%
# !cuopt_cli --method=3 --ordering=0 set-cover-model.mps.bz2
# Out:
# Setting parameter method to 3
# Setting parameter ordering to 0
# Reading file set-cover-model.mps.bz2
# cuOpt version: 25.10.0, git hash: ab1cc2b, host arch: x86_64, device archs: 70-real,75-real,80-real,86-real,90a-real,100f-real,120a-real,120
# CPU: Intel(R) Xeon(R) CPU @ 2.20GHz, threads (physical/logical): 1/2, RAM: 1.76 GiB
# CUDA 12.9, device: Tesla T4 (ID 0), VRAM: 14.74 GiB
# CUDA device UUID: ffffffa2ffffffa0ffffff94ffffffc8-2ff
#
# Solving a problem with 10000 constraints, 1102008 variables (0 integers), and 20442268 nonzeros
# Problem scaling:
# Objective coefficents range:          [3e+05, 8e+07]
# Constraint matrix coefficients range: [1e+00, 1e+00]
# Constraint rhs / bounds range:        [0e+00, 1e+00]
# Variable bounds range:                [0e+00, 1e+00]
#
# Third-party presolve is disabled, skipping
# Objective offset 0.000000 scaling_factor 1.000000
# Folding: Skipping
# Presolved problem: 10000 constraints 1112008 variables 20452268 nonzeros
# Scaling matrix. Maximum column norm 5.916080e+00
# Barrier solver: 10000 constraints, 1112008 variables, 20452268 nonzeros
#
# Upper bounds                : 1102008
# Density estimator time      : 0.00s
# Linear system               : ADAT
# cuDSS Version               : 0.7.0
# cuDSS Threading layer       : libcudss_mtlayer_gomp.so.0
# ADAT time                   : 0.65s
# ADAT nonzeros               : 8.89e+07
# ADAT density                : 0.89
# Reordering time             : 6.81s
# Symbolic factorization time : 10.95s
# Total symbolic time         : 17.76s
# Symbolic nonzeros in factor : 4.95e+07
#
#                   Objective                         Infeasibility        Time
# Iter   Primal              Dual                Primal   Dual    Compl.   Elapsed
#   0   +9.725598558236e+13 -4.586413355809e+19 8.28e+03 1.00e+01 9.75e+13 32.0
#   1   +3.632997367600e+13 -2.571301892249e+19 4.14e+02 3.95e-08 6.10e-01 36.0
#   2   +3.004081196130e+13 -3.447868397257e+18 4.14e+01 3.95e-09 3.75e-01 39.9
#   3   +2.941540568517e+13 -3.464383614875e+17 4.14e+00 3.95e-10 7.48e-03 43.8
#   4   +2.935040187212e+13 -3.467278694050e+16 4.14e-01 3.96e-11 8.77e-05 47.8
#   5   +2.931921923929e+13 -3.495672136918e+15 4.14e-02 4.02e-12 1.00e-06 51.8
#   6   +2.907049079746e+13 -3.773286568526e+14 4.14e-03 4.63e-13 1.28e-06 55.7
#   7   +2.671256907745e+13 -5.997772303258e+13 4.14e-04 9.91e-14 1.47e-06 59.7
#   8   +1.258598991833e+13 -1.682876447800e+13 4.14e-05 3.66e-14 3.39e-06 63.7
#   9   +4.440398170372e+12 -5.118618251615e+12 9.38e-06 1.30e-14 5.42e-06 67.7
#  41   +7.621822032767e+09 +7.549119076357e+09 4.71e-14 2.34e-16 5.54e-07 194.2
#  42   +7.608067063872e+09 +7.560280695625e+09 7.46e-14 2.07e-16 3.39e-07 198.2
#  43   +7.597823706069e+09 +7.567295612612e+09 1.37e-13 1.92e-16 1.62e-07 202.1
#  44   +7.590793449227e+09 +7.573055964900e+09 1.27e-13 1.83e-16 6.59e-08 206.1
#  45   +7.587155383206e+09 +7.577020335616e+09 1.66e-13 2.44e-16 2.33e-08 210.0
#  46   +7.584946936373e+09 +7.578952254596e+09 2.11e-13 2.52e-16 7.23e-09 214.0
#
# Optimal solution found in 46 iterations and 213.97s
# Objective +7.58494694e+09
# Primal infeasibility (abs/rel): 4.22e-13/2.11e-13
# Dual infeasibility   (abs/rel): 6.37e-09/2.52e-16
# Complementarity gap  (abs/rel): 5.49e+01/7.23e-09
#
# Unscaled Primal infeasibility   (abs/rel): 4.21e-13/2.10e-13
# Unscaled Dual infeasibility     (abs/rel): 3.17e-08/3.81e-16
# Post-solve Primal infeasibility (abs/rel): 4.21e-13/2.10e-13
# Post-solve Dual infeasibility   (abs/rel): 3.17e-08/3.81e-16
# Barrier finished in 216.90 seconds

# %% [markdown]
# We now solve the same LP with the approximate minimum degree ordering.

# %%
# !cuopt_cli --method=3 --ordering=1 set-cover-model.mps.bz2
# Out:
# Setting parameter method to 3
# Setting parameter ordering to 1
# Reading file set-cover-model.mps.bz2
# cuOpt version: 25.10.0, git hash: ab1cc2b, host arch: x86_64, device archs: 70-real,75-real,80-real,86-real,90a-real,100f-real,120a-real,120
# CPU: Intel(R) Xeon(R) CPU @ 2.20GHz, threads (physical/logical): 1/2, RAM: 3.58 GiB
# CUDA 12.9, device: Tesla T4 (ID 0), VRAM: 14.74 GiB
# CUDA device UUID: ffffffa2ffffffa0ffffff94ffffffc8-2ff
#
# Solving a problem with 10000 constraints, 1102008 variables (0 integers), and 20442268 nonzeros
# Problem scaling:
# Objective coefficents range:          [3e+05, 8e+07]
# Constraint matrix coefficients range: [1e+00, 1e+00]
# Constraint rhs / bounds range:        [0e+00, 1e+00]
# Variable bounds range:                [0e+00, 1e+00]
#
# Third-party presolve is disabled, skipping
# Objective offset 0.000000 scaling_factor 1.000000
# Folding: Skipping
# Presolved problem: 10000 constraints 1112008 variables 20452268 nonzeros
# Scaling matrix. Maximum column norm 5.916080e+00
# Barrier solver: 10000 constraints, 1112008 variables, 20452268 nonzeros
#
# Upper bounds                : 1102008
# Density estimator time      : 0.00s
# Linear system               : ADAT
# cuDSS Version               : 0.7.0
# cuDSS Threading layer       : libcudss_mtlayer_gomp.so.0
# ADAT time                   : 0.61s
# ADAT nonzeros               : 8.89e+07
# ADAT density                : 0.89
# Reordering algorithm        : AMD
# Reordering time             : 2.86s
# Symbolic factorization time : 9.39s
# Total symbolic time         : 12.25s
# Symbolic nonzeros in factor : 5.00e+07
#
#                   Objective                         Infeasibility        Time
# Iter   Primal              Dual                Primal   Dual    Compl.   Elapsed
#  31   +8.206761568129e+09 +6.938128755540e+09 3.72e-12 1.86e-16 6.30e-06 126.3
#  32   +8.050906923791e+09 +7.052474621363e+09 2.27e-12 2.34e-16 6.06e-06 129.6
#  33   +7.960177941322e+09 +7.193657424090e+09 1.61e-12 1.70e-16 5.59e-06 132.9
#  34   +7.870816311049e+09 +7.266800906614e+09 9.69e-13 1.77e-16 4.30e-06 136.1
#  35   +7.803667519537e+09 +7.345220075005e+09 6.57e-13 1.95e-16 4.85e-06 139.4
#  36   +7.756066147249e+09 +7.380628049348e+09 4.27e-13 1.65e-16 4.79e-06 142.6
#  37   +7.713242389439e+09 +7.433325936564e+09 2.86e-13 1.67e-16 3.73e-06 145.9
#  38   +7.688328953394e+09 +7.490412010277e+09 2.16e-13 1.76e-16 2.55e-06 149.1
#  39   +7.665429822601e+09 +7.506183055292e+09 1.37e-13 1.74e-16 1.48e-06 152.4
#  40   +7.636992308350e+09 +7.533023173057e+09 7.48e-14 2.03e-16 1.01e-06 155.6
#  41   +7.621822670355e+09 +7.549118929609e+09 4.53e-14 2.22e-16 5.54e-07 158.9
#  42   +7.608067209732e+09 +7.560280698058e+09 4.57e-14 1.73e-16 3.39e-07 162.2
#  43   +7.597824056115e+09 +7.567295572774e+09 6.15e-14 1.74e-16 1.62e-07 165.4
#  44   +7.590793605105e+09 +7.573055945704e+09 1.04e-13 1.71e-16 6.59e-08 168.6
#  45   +7.587155478552e+09 +7.577020332814e+09 1.02e-13 2.69e-16 2.33e-08 171.9
#  46   +7.584946994566e+09 +7.578952251706e+09 2.55e-13 1.99e-16 7.23e-09 175.1
#
# Optimal solution found in 46 iterations and 175.14s
# Objective +7.58494699e+09
# Primal infeasibility (abs/rel): 5.09e-13/2.55e-13
# Dual infeasibility   (abs/rel): 5.05e-09/1.99e-16
# Complementarity gap  (abs/rel): 5.49e+01/7.23e-09
#
# Unscaled Primal infeasibility   (abs/rel): 5.08e-13/2.54e-13
# Unscaled Dual infeasibility     (abs/rel): 2.98e-08/3.59e-16
# Post-solve Primal infeasibility (abs/rel): 5.08e-13/2.54e-13
# Post-solve Dual infeasibility   (abs/rel): 2.98e-08/3.59e-16
# Barrier finished in 178.26 seconds

# %% [markdown]
# We see an improvement from 216 seconds to 178 seconds with using the AMD ordering on this problem.

# %% [markdown]
# #Presolve
# cuOpt can perform other operations to reduce the size of the linear program. This process is called presolve. Currently, cuOpt links against the open-source presolver Papilo. By default, Papilo is disabled for LPs. This is because in our experiments, on average, we find it faster to solve the original problem directly, rather than applying extensive presolve reductions.
#
# However, your linear program may benefit from enabling presolve. Let's download an LP where presolve is able to reduce the problem size.

# %%
# !wget https://plato.asu.edu/ftp/lptestset/woodlands09.mps.bz2
# Out:
# --2025-10-10 19:24:23--  https://plato.asu.edu/ftp/lptestset/woodlands09.mps.bz2
# Resolving plato.asu.edu (plato.asu.edu)... 129.219.51.85
# Connecting to plato.asu.edu (plato.asu.edu)|129.219.51.85|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7064631 (6.7M) [application/x-bzip2]
# Saving to: ‘woodlands09.mps.bz2’
#
# woodlands09.mps.bz2 100%[===================>]   6.74M  4.04MB/s    in 1.7s
#
# 2025-10-10 19:24:25 (4.04 MB/s) - ‘woodlands09.mps.bz2’ saved [7064631/7064631]

# %% [markdown]
#  To enable presolve for linear programs, set the presolve option to true.

# %%
# !cuopt_cli --method=3 --presolve=t woodlands09.mps.bz2
# Out:
# Setting parameter method to 3
# Setting parameter presolve to true
# Running file woodlands09.mps.bz2
# cuOpt version: 25.10.0, git hash: e9a4f81, host arch: x86_64, device archs: 70-real,75-real,80-real,86-real,90a-real,100f-real,120a-real,120
# CPU: Intel(R) Xeon(R) CPU @ 2.00GHz, threads (physical/logical): 1/2, RAM: 1.10 GiB
# CUDA 12.9, device: Tesla T4 (ID 0), VRAM: 14.74 GiB
# CUDA device UUID: ffffffe4ffffff857a00-ffffff82ffffffe
#
# Unpresolved problem: 194599 constraints, 382147 variables, 2646003 nonzeros
# Calling Papilo presolver
# Disabling the presolver methods that do not support dual postsolve
# Presolve status: reduced the problem
# Presolve removed: 23911 constraints, 22008 variables, 586657 nonzeros
# Presolved problem: 170688 constraints, 360139 variables, 2059346 nonzeros
# Papilo presolve time: 1.582778
# Solving a problem with 170688 constraints 360139 variables (0 integers) and 2059346 nonzeros
# Objective offset 0.000000 scaling_factor 1.000000
# Folding: Number of colors exceeds threshold
# Folding: Coloring aborted in 0.94 seconds
# Presolved problem: 170688 constraints 374251 variables 2073458 nonzeros
# Scaling matrix. Maximum column norm 1.077033e+01
# Barrier solver: 170688 constraints, 374251 variables, 2073458 nonzeros
#
# Upper bounds                : 360139
# Density estimator time      : 0.00s
# Linear system               : ADAT
# cuDSS Version               : 0.7.0
# cuDSS Threading layer       : libcudss_mtlayer_gomp.so.0
# ADAT time                   : 0.04s
# ADAT nonzeros               : 6.02e+06
# ADAT density                : 0.00
# Reordering time             : 2.61s
# Symbolic factorization time : 0.35s
# Total symbolic time         : 2.95s
# Symbolic nonzeros in factor : 8.69e+06
#
#                   Objective                         Infeasibility        Time
# Iter   Primal              Dual                Primal   Dual    Compl.   Elapsed
#   0   +1.220847380947e+04 -1.114601746710e+09 4.57e+03 1.00e+01 2.45e+04 4.6
#   1   +1.682023354070e+03 -7.214586330200e+08 1.59e+01 5.31e-01 3.64e+00 5.0
#   2   +4.638606137163e+02 -1.725231559596e+08 4.22e+00 5.31e-02 4.08e+00 5.3
#   3   +1.119954004434e+02 -5.018947604379e+07 8.32e-01 1.29e-02 1.33e+00 5.7
#   4   +6.797567048745e+01 -2.187431807079e+07 4.08e-01 4.99e-03 5.54e-01 6.0
#   5   +5.196486085512e+01 -1.664936735513e+07 2.53e-01 3.14e-03 2.66e+00 6.3
#   6   +3.508708266112e+01 -1.153263757300e+07 9.02e-02 1.87e-03 3.06e+00 6.7
#   7   +3.074114823612e+01 -3.169093348356e+06 4.85e-02 3.04e-04 1.58e+00 7.0
#   8   +2.682618074775e+01 -6.504318210725e+05 1.10e-02 4.95e-05 7.21e-01 7.4
#   9   +2.577312272251e+01 -7.215187014878e+04 1.20e-03 5.32e-06 4.21e-02 7.7
#  10   +2.537557940325e+01 -1.005910290971e+04 1.20e-04 7.43e-07 5.17e-04 8.0
#  11   +2.301742125644e+01 -3.275585299734e+03 1.26e-05 2.41e-07 2.50e-04 8.4
#  12   +1.702083867015e+01 -1.793026371930e+03 6.54e-06 9.60e-08 1.04e-03 8.7
#  13   +7.694652266363e+00 -1.400876338685e+03 2.45e-06 5.82e-08 4.67e-03 9.1
#  14   +1.649405331713e+00 -2.364604510297e+02 4.15e-07 9.46e-09 7.84e-03 9.4
#  15   +1.886111820729e-01 -3.473732213543e+01 4.50e-08 1.39e-09 4.31e-04 9.7
#  16   +1.967336932975e-02 -3.787795941088e+00 4.70e-09 1.51e-10 4.42e-05 10.1
#  17   +1.970890609239e-03 -3.790660328935e-01 4.71e-10 1.54e-11 5.99e-07 10.4
#  18   +1.971209508184e-04 -3.790688552744e-02 4.71e-11 2.81e-12 6.06e-09 10.8
#
# Optimal solution found in 18 iterations and 10.78s
# Objective +1.97120951e-04
# Primal infeasibility (abs/rel): 1.84e-09/4.71e-11
# Dual infeasibility   (abs/rel): 5.30e-12/2.81e-12
# Complementarity gap  (abs/rel): 6.06e-09/6.06e-09
#
# Unscaled Primal infeasibility   (abs/rel): 1.84e-09/4.71e-11
# Unscaled Dual infeasibility     (abs/rel): 6.91e-11/7.67e-12
# Post-solve Primal infeasibility (abs/rel): 1.84e-09/4.71e-11
# Post-solve Dual infeasibility   (abs/rel): 6.91e-11/7.67e-12
# Barrier finished in 12.49 seconds
# Post-solve status: succeeded

# %% [markdown]
# Note that Papilo includes presolve reductions that do not support dual post-solve. Meaning that Papilo cannot extract the optimal dual variables for the original problem from the solution of the presolved problem. If you need the dual solution to the linear program, you can set the parameter “dual-postsolve” to true. This will disable all reductions that do not support dual post-solve, and allow you to recover the dual solution. However, the presolved linear program may be larger in this case.

# %%
# !cuopt_cli --method=3 --presolve=t --dual-postsolve=t woodlands09.mps.bz2
# Out:
# Setting parameter dual_postsolve to true
# Setting parameter method to 3
# Setting parameter presolve to true
# Running file woodlands09.mps.bz2
# cuOpt version: 25.10.0, git hash: e9a4f81, host arch: x86_64, device archs: 70-real,75-real,80-real,86-real,90a-real,100f-real,120a-real,120
# CPU: Intel(R) Xeon(R) CPU @ 2.00GHz, threads (physical/logical): 1/2, RAM: 1.11 GiB
# CUDA 12.9, device: Tesla T4 (ID 0), VRAM: 14.74 GiB
# CUDA device UUID: ffffffe4ffffff857a00-ffffff82ffffffe
#
# Unpresolved problem: 194599 constraints, 382147 variables, 2646003 nonzeros
# Calling Papilo presolver
# Disabling the presolver methods that do not support dual postsolve
# Presolve status: reduced the problem
# Presolve removed: 23911 constraints, 22008 variables, 586657 nonzeros
# Presolved problem: 170688 constraints, 360139 variables, 2059346 nonzeros
# Papilo presolve time: 1.608108
# Solving a problem with 170688 constraints 360139 variables (0 integers) and 2059346 nonzeros
# Objective offset 0.000000 scaling_factor 1.000000
# Folding: Number of colors exceeds threshold
# Folding: Coloring aborted in 0.92 seconds
# Presolved problem: 170688 constraints 374251 variables 2073458 nonzeros
# Scaling matrix. Maximum column norm 1.077033e+01
